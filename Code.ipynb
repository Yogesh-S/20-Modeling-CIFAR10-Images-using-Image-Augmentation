# %% [markdown]
# # Convolutional Neural Networks
# ---
# In this notebook, we train a **CNN** to classify images from the CIFAR-10 database.
#
# The images in this database are small color images that fall into one of ten classes; some example images are pictured below.
#
# <img src='cifar_data.png' width=70% height=70% />

# %%
import torch
import numpy as np

from torch import nn, optim

from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.optim as optim

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# Since these are larger (32x32x3) images, it may prove useful to speed up the training time by using a GPU. CUDA is a parallel computing platform and CUDA Tensors are the same as typical Tensors, except they utilize GPU's for computation.

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ---
# ## Load and Augment the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Let us load the training and test data, split the training data into a training and validation set, then create DataLoaders for each of these sets of data.
#
# ### Augmentation
#
# Let us perform some simple [data augmentation](https://medium.com/nanonets/how-to-use-deep-learning-when-you-have-limited-data-part-2-data-augmentation-c26971dc8ced) by randomly flipping and rotating the given image data. We do this by defining a torchvision [transform](https://pytorch.org/docs/stable/torchvision/transforms.html).
#
# This type of data augmentation should add some positional variety to these images, so that when we train a model on this data, it will be robust in the face of geometric changes (i.e. it will recognize a ship, no matter which direction it is facing).

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(), # randomly flip
    transforms.RandomRotation(10),     # randomly rotate by 10°
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[15])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
# Let us define CNN architecture using the layers below:
# * [Convolutional layers](https://pytorch.org/docs/stable/nn.html#conv2d), which can be thought of as stack of filtered images.
# * [Maxpooling layers](https://pytorch.org/docs/stable/nn.html#maxpool2d), which reduce the x-y size of an input, keeping only the most _active_ pixels from the previous layer.
# * The usual Linear + Dropout layers to avoid overfitting and produce a 10-dim output.
#
# A network with 2 convolutional layers and a fully-connected layer is shown in the image below.
#
# <img src='2_layer_conv.png' height=50% width=50% />
#
# The more convolutional layers we include, the more complex patterns in color and shape a model can detect. Conventionally we  include 2 or 3 convolutional layers as well as linear layers + dropout in between to avoid overfitting.
#
# It's good practice to look at existing research and implementations of related [Pytorch models](https://github.com/pytorch/tutorials/blob/master/beginner_source/blitz/cifar10_tutorial.py) or [Keras example](https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py) to help decide on a final structure.
#
# #### Output volume for a convolutional layer
#
# To compute the output size of a given convolutional layer we can perform the following calculation (taken from [Stanford's cs231n course](http://cs231n.github.io/convolutional-networks/#layers)):
# > We can compute the spatial size of the output volume as a function of the input volume size (W), the kernel/filter size (F), the stride with which they are applied (S), and the amount of zero padding used (P) on the border. The correct formula for calculating how many neurons define the output_W is given by `((W−F+2P)/S)+1`.
#
# For example for a 7x7 input and a 3x3 filter with stride 1 and pad 0 we would get a 5x5 output. With stride 2 we would get a 3x3 output.

# %%
# create a complete CNN
model = nn.Sequential(nn.Conv2d(3, 16, 3, padding = 1),
                      nn.ReLU(),
                      nn.MaxPool2d(2, 2),
                      nn.Conv2d(16, 32, 3, padding = 1),
                      nn.ReLU(),
                      nn.MaxPool2d(2, 2),
                      nn.Conv2d(32, 64, 3, padding = 1),
                      nn.ReLU(),
                      nn.MaxPool2d(2, 2),
                      nn.Flatten(start_dim=1),
                      nn.Dropout(p=0.25),
                      nn.Linear(1024,512),
                      nn.ReLU(),
                      nn.Dropout(p=0.25),
                      nn.Linear(512,512),
                      nn.ReLU(),
                      nn.Dropout(p=0.25),
                      nn.Linear(512,10))

print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Sequential(
#   (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU()
#   (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (9): Flatten()
#   (10): Dropout(p=0.25, inplace=False)
#   (11): Linear(in_features=1024, out_features=512, bias=True)
#   (12): ReLU()
#   (13): Dropout(p=0.25, inplace=False)
#   (14): Linear(in_features=512, out_features=512, bias=True)
#   (15): ReLU()
#   (16): Dropout(p=0.25, inplace=False)
#   (17): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ---
# ## Train the Network
#
# Let us see how the training and validation loss decreases over time; if the validation loss ever increases it indicates possible overfitting.

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# number of epochs to train the model
n_epochs = 50

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_augmented.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 2.279457 	Validation Loss: 2.119630
# Validation loss decreased (inf --> 2.119630).  Saving model ...
# Epoch: 2 	Training Loss: 1.960361 	Validation Loss: 1.738333
# Validation loss decreased (2.119630 --> 1.738333).  Saving model ...
# Epoch: 3 	Training Loss: 1.670889 	Validation Loss: 1.602561
# Validation loss decreased (1.738333 --> 1.602561).  Saving model ...
# Epoch: 4 	Training Loss: 1.531874 	Validation Loss: 1.422156
# Validation loss decreased (1.602561 --> 1.422156).  Saving model ...
# Epoch: 5 	Training Loss: 1.420935 	Validation Loss: 1.309201
# Validation loss decreased (1.422156 --> 1.309201).  Saving model ...
# Epoch: 6 	Training Loss: 1.330213 	Validation Loss: 1.237823
# Validation loss decreased (1.309201 --> 1.237823).  Saving model ...
# Epoch: 7 	Training Loss: 1.252537 	Validation Loss: 1.178287
# Validation loss decreased (1.237823 --> 1.178287).  Saving model ...
# Epoch: 8 	Training Loss: 1.193800 	Validation Loss: 1.095924
# Validation loss decreased (1.178287 --> 1.095924).  Saving model ...
# Epoch: 9 	Training Loss: 1.139327 	Validation Loss: 1.039449
# Validation loss decreased (1.095924 --> 1.039449).  Saving model ...
# Epoch: 10 	Training Loss: 1.091168 	Validation Loss: 1.002904
# Validation loss decreased (1.039449 --> 1.002904).  Saving model ...
# Epoch: 11 	Training Loss: 1.049570 	Validation Loss: 0.984516
# Validation loss decreased (1.002904 --> 0.984516).  Saving model ...
# Epoch: 12 	Training Loss: 1.010590 	Validation Loss: 0.969009
# Validation loss decreased (0.984516 --> 0.969009).  Saving model ...
# Epoch: 13 	Training Loss: 0.984687 	Validation Loss: 0.904815
# Validation loss decreased (0.969009 --> 0.904815).  Saving model ...
# Epoch: 14 	Training Loss: 0.955412 	Validation Loss: 0.889018
# Validation loss decreased (0.904815 --> 0.889018).  Saving model ...
# Epoch: 15 	Training Loss: 0.927195 	Validation Loss: 0.865952
# Validation loss decreased (0.889018 --> 0.865952).  Saving model ...
# Epoch: 16 	Training Loss: 0.906424 	Validation Loss: 0.853725
# Validation loss decreased (0.865952 --> 0.853725).  Saving model ...
# Epoch: 17 	Training Loss: 0.882920 	Validation Loss: 0.838470
# Validation loss decreased (0.853725 --> 0.838470).  Saving model ...
# Epoch: 18 	Training Loss: 0.858559 	Validation Loss: 0.823677
# Validation loss decreased (0.838470 --> 0.823677).  Saving model ...
# Epoch: 19 	Training Loss: 0.842056 	Validation Loss: 0.791014
# Validation loss decreased (0.823677 --> 0.791014).  Saving model ...
# Epoch: 20 	Training Loss: 0.827057 	Validation Loss: 0.780541
# Validation loss decreased (0.791014 --> 0.780541).  Saving model ...
# Epoch: 21 	Training Loss: 0.805131 	Validation Loss: 0.771322
# Validation loss decreased (0.780541 --> 0.771322).  Saving model ...
# Epoch: 22 	Training Loss: 0.794753 	Validation Loss: 0.739454
# Validation loss decreased (0.771322 --> 0.739454).  Saving model ...
# Epoch: 23 	Training Loss: 0.777270 	Validation Loss: 0.740367
# Epoch: 24 	Training Loss: 0.766898 	Validation Loss: 0.730784
# Validation loss decreased (0.739454 --> 0.730784).  Saving model ...
# Epoch: 25 	Training Loss: 0.749892 	Validation Loss: 0.756859
# Epoch: 26 	Training Loss: 0.735502 	Validation Loss: 0.722080
# Validation loss decreased (0.730784 --> 0.722080).  Saving model ...
# Epoch: 27 	Training Loss: 0.724407 	Validation Loss: 0.714833
# Validation loss decreased (0.722080 --> 0.714833).  Saving model ...
# Epoch: 28 	Training Loss: 0.711466 	Validation Loss: 0.697990
# Validation loss decreased (0.714833 --> 0.697990).  Saving model ...
# Epoch: 29 	Training Loss: 0.704240 	Validation Loss: 0.697363
# Validation loss decreased (0.697990 --> 0.697363).  Saving model ...
# Epoch: 30 	Training Loss: 0.691834 	Validation Loss: 0.683343
# Validation loss decreased (0.697363 --> 0.683343).  Saving model ...
# Epoch: 31 	Training Loss: 0.675033 	Validation Loss: 0.672138
# Validation loss decreased (0.683343 --> 0.672138).  Saving model ...
# Epoch: 32 	Training Loss: 0.675709 	Validation Loss: 0.671190
# Validation loss decreased (0.672138 --> 0.671190).  Saving model ...
# Epoch: 33 	Training Loss: 0.659797 	Validation Loss: 0.675573
# Epoch: 34 	Training Loss: 0.652096 	Validation Loss: 0.671393
# Epoch: 35 	Training Loss: 0.642438 	Validation Loss: 0.672192
# Epoch: 36 	Training Loss: 0.634616 	Validation Loss: 0.647831
# Validation loss decreased (0.671190 --> 0.647831).  Saving model ...
# Epoch: 37 	Training Loss: 0.630965 	Validation Loss: 0.650551
# Epoch: 38 	Training Loss: 0.620549 	Validation Loss: 0.643575
# Validation loss decreased (0.647831 --> 0.643575).  Saving model ...
# Epoch: 39 	Training Loss: 0.613702 	Validation Loss: 0.652960
# Epoch: 40 	Training Loss: 0.603731 	Validation Loss: 0.648831
# Epoch: 41 	Training Loss: 0.602292 	Validation Loss: 0.642104
# Validation loss decreased (0.643575 --> 0.642104).  Saving model ...
# Epoch: 42 	Training Loss: 0.590665 	Validation Loss: 0.654812
# Epoch: 43 	Training Loss: 0.584788 	Validation Loss: 0.633302
# Validation loss decreased (0.642104 --> 0.633302).  Saving model ...
# Epoch: 44 	Training Loss: 0.575748 	Validation Loss: 0.629129
# Validation loss decreased (0.633302 --> 0.629129).  Saving model ...
# Epoch: 45 	Training Loss: 0.570521 	Validation Loss: 0.626027
# Validation loss decreased (0.629129 --> 0.626027).  Saving model ...
# Epoch: 46 	Training Loss: 0.560965 	Validation Loss: 0.620870
# Validation loss decreased (0.626027 --> 0.620870).  Saving model ...
# Epoch: 47 	Training Loss: 0.553586 	Validation Loss: 0.615224
# Validation loss decreased (0.620870 --> 0.615224).  Saving model ...
# Epoch: 48 	Training Loss: 0.554299 	Validation Loss: 0.635546
# Epoch: 49 	Training Loss: 0.541690 	Validation Loss: 0.615538
# Epoch: 50 	Training Loss: 0.540313 	Validation Loss: 0.632238

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_augmented.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Let us test trained model on previously unseen data!

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.624372
#
# Test Accuracy of airplane: 84% (843/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 69% (696/1000)
# Test Accuracy of   cat: 66% (661/1000)
# Test Accuracy of  deer: 73% (732/1000)
# Test Accuracy of   dog: 63% (631/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 86% (862/1000)
# Test Accuracy of  ship: 86% (865/1000)
# Test Accuracy of truck: 83% (837/1000)
#
# Test Accuracy (Overall): 78% (7838/10000)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images.cpu()[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
